# %% [markdown]
# 一些写毕节用的HTML语法

# %% [markdown]
# 1.将文字更改为<span style="color:red;">红色</span>，<span style="color:green;">绿色</span>，<span style="color:blue;">蓝色</span>

# %% [markdown]
# ‘<span style="color:red;">红色文字</span>
# <span style="color:green;">绿色文字</span>
# <span style="color:blue;">蓝色文字</span>
